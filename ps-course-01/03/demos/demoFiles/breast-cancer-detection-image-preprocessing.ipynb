# %% [markdown]
# # Get images from Kaggle

# %% [markdown]
# ## Install Kaggle API client

# %%
# %%bash
# pip install kaggle
# Out:
# Collecting kaggle
#   Downloading https://files.pythonhosted.org/packages/78/3a/64a6447e5faa313b70cb555e21b5a30718c95bcc4902d91784b57fbab737/kaggle-1.5.3.tar.gz (54kB)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/ec2-user/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages (from kaggle) (1.23)
# Requirement already satisfied: six>=1.10 in /home/ec2-user/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages (from kaggle) (1.11.0)
# Requirement already satisfied: certifi in /home/ec2-user/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages (from kaggle) (2019.3.9)
# Requirement already satisfied: python-dateutil in /home/ec2-user/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages (from kaggle) (2.7.3)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages (from kaggle) (2.20.1)
# Collecting tqdm (from kaggle)
#   Downloading https://files.pythonhosted.org/packages/45/af/685bf3ce889ea191f3b916557f5677cc95a5e87b2fa120d74b5dd6d049d0/tqdm-4.32.1-py2.py3-none-any.whl (49kB)
# Collecting python-slugify (from kaggle)
#   Downloading https://files.pythonhosted.org/packages/c1/19/c3cf1dc65e89aa999f85a4a3a4924ccac765a6964b405d487b7b7c8bb39f/python-slugify-3.0.2.tar.gz
# Requirement already satisfied: idna<2.8,>=2.5 in /home/ec2-user/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages (from requests->kaggle) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/ec2-user/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages (from requests->kaggle) (3.0.4)
# Collecting text-unidecode==1.2 (from python-slugify->kaggle)
#   Downloading https://files.pythonhosted.org/packages/79/42/d717cc2b4520fb09e45b344b1b0b4e81aa672001dd128c180fabc655c341/text_unidecode-1.2-py2.py3-none-any.whl (77kB)
# Building wheels for collected packages: kaggle, python-slugify
#   Running setup.py bdist_wheel for kaggle: started
#   Running setup.py bdist_wheel for kaggle: finished with status 'done'
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/ee/97/c5/87dcdc9434fe4e632ed5945e31a03703af229db178ef6a00e8
#   Running setup.py bdist_wheel for python-slugify: started
#   Running setup.py bdist_wheel for python-slugify: finished with status 'done'
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/16/7f/c3/6b0582283ad589d68a306da924a78c74546e010d8106b9b3a9
# Successfully built kaggle python-slugify
# Installing collected packages: tqdm, text-unidecode, python-slugify, kaggle
# Successfully installed kaggle-1.5.3 python-slugify-3.0.2 text-unidecode-1.2 tqdm-4.32.1
# You are using pip version 10.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# ## Move API key to where Kaggle expects it and change file permissions

# %%
# %%bash
#
# mkdir /home/ec2-user/.kaggle/
# mv /home/ec2-user/SageMaker/kaggle.json /home/ec2-user/.kaggle/
# chmod 600 /home/ec2-user/.kaggle/kaggle.json

# %%
# %%bash
#
# kaggle datasets list --user paultimothymooney
# Out:
# ref                                                          title                                               size  lastUpdated          downloadCount
# -----------------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------
# paultimothymooney/denver-crime-data                          Denver Crime Data                                   88MB  2019-05-24 03:12:08           1810
# paultimothymooney/police-pedestrian-stops-and-vehicle-stops  Denver Police Pedestrian Stops and Vehicle Stops    68MB  2019-05-24 03:12:07            254
# paultimothymooney/chest-xray-pneumonia                       Chest X-Ray Images (Pneumonia)                       1GB  2018-03-24 19:41:59          11783
# paultimothymooney/mueller-report                             The Mueller Report                                 124MB  2019-04-20 20:21:27            318
# paultimothymooney/chiu-2015                                  Segmentation of OCT images (DME)                   170MB  2018-08-06 18:52:02            446
# paultimothymooney/kermany2018                                Retinal OCT Images (optical coherence tomography)    5GB  2018-03-25 15:04:56           3033
# paultimothymooney/farsiu-2014                                Segmentation of OCT images (AMD)                    17GB  2018-08-10 19:07:06            378
# paultimothymooney/russian-political-influence-campaigns      Internet Research Agency (IRA) Social Media Data    10GB  2018-08-03 21:35:48            427
# paultimothymooney/medical-speech-transcription-and-intent    Medical Speech, Transcription, and Intent            3GB  2019-02-24 04:37:00            119
# paultimothymooney/blood-cells                                Blood Cell Images                                  106MB  2018-04-21 21:06:13           7242
# paultimothymooney/python-developers-survey-2018              Python Developers Survey (2017 & 2018)               4MB  2019-02-08 16:43:53            221
# paultimothymooney/scispacy-pretrained-models                 SciSpacy Pre-trained Models                        493MB  2019-02-24 15:28:22             28
# paultimothymooney/breast-histopathology-images               Breast Histopathology Images                         1GB  2017-12-19 05:46:40           5611
# paultimothymooney/boulder-911-police-call-logs               Boulder Police Call Logs                           159KB  2019-05-24 03:12:07             72
# paultimothymooney/lord-of-the-rings-data                     Lord of the Rings Data                              87KB  2018-09-04 00:22:35            475
# paultimothymooney/ptm-strava-data                            PTM Strava Data                                      1MB  2018-04-04 00:28:40             44
# paultimothymooney/cell-cycle-experiments                     Cell Cycle Experiments                              41MB  2019-02-13 19:23:23              3
# paultimothymooney/zipfiles                                   The Simpsons Characters Data (zipfiles)            519MB  2017-11-03 18:20:30             83
# paultimothymooney/sample-images-for-kaggle-demos             Sample Images for Kaggle Demos                       1MB  2018-07-17 01:54:58             50
# paultimothymooney/poetry                                     Song Lyrics                                          2MB  2018-08-18 18:47:12            378

# %% [markdown]
# ## Download the breast cancer detection dataset

# %%
# %%bash
#
# kaggle datasets download --unzip paultimothymooney/breast-histopathology-images
# Out:
# Downloading breast-histopathology-images.zip to /home/ec2-user/SageMaker
# 100%|██████████| 1.49G/1.49G [00:16<00:00, 98.1MB/s]

# %% [markdown]
# ## Unzip the dataset to the images directory and remove the original ZIP file

# %%
# %%bash
#
# unzip IDC_regular_ps50_idx5.zip -d images
# rm -rf IDC_regular_ps50_idx5.zip
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## Reorganize files in the images directory into two subdirectories, corresponding to the two classes we have (0 and 1). This will be useful when converting images to RecordIO format

# %%
# %%bash
#
# mkdir images/0
# mkdir images/1

# %%
import os

# %%
for path, subdirs, files in os.walk('images'):
    for name in files:
        filename = os.path.join(path, name)
        if name.endswith('class0.png'):
            destination_class = '0'
        else:
            destination_class = '1'
        os.rename(filename, os.path.join('images', destination_class, name))

# %%
# %%bash
# shopt -s extglob
# cd images
# rm -rf !("0"|"1")

# %% [markdown]
# # Explore the images

# %% [markdown]
# ## Count the number of images for each class

# %%
# %%bash
# cd images/0
# ls -1 | wc -l
# Out:
# 198738

# %%
# %%bash
# cd images/1
# ls -1 | wc -l
# Out:
# 78786

# %% [markdown]
# ## Show an image with no cancer (class 0)

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('images/0/8975_idx5_x2851_y1201_class0.png')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# ## Show an image with cancer (class 1)

# %%
img = mpimg.imread('images/1/9075_idx5_x801_y801_class1.png')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# # Convert images to the RecordIO format and upload to S3

# %% [markdown]
# ## Get the im2rec script from Apache MXNet Github repository

# %%
# %%bash
#
# wget https://raw.githubusercontent.com/apache/incubator-mxnet/master/tools/im2rec.py
# chmod +x im2rec.py
# Out:
# --2019-05-24 18:48:46--  https://raw.githubusercontent.com/apache/incubator-mxnet/master/tools/im2rec.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.200.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.200.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15838 (15K) [text/plain]
# Saving to: ‘im2rec.py’
#
#      0K .......... .....                                      100% 16.7M=0.001s
#
# 2019-05-24 18:48:46 (16.7 MB/s) - ‘im2rec.py’ saved [15838/15838]

# %% [markdown]
# ## Create the .lst files needed for creating the .rec files for train and test datasets

# %%
# %%bash
#
# python im2rec.py --list --recursive --test-ratio 0.3 --train-ratio 0.7 images images/
# Out:
# 0 0
# 1 1

# %% [markdown]
# ## Create the .rec files for train and test datasets

# %%
# %%bash
#
# python im2rec.py --num-thread 4 --pass-through images_train.lst images
# python im2rec.py --num-thread 4 --pass-through images_test.lst images
# Out:
# Creating .rec file from /home/ec2-user/SageMaker/images_train.lst in /home/ec2-user/SageMaker
# time: 0.0007662773132324219  count: 0
# time: 0.19082427024841309  count: 1000
# time: 0.181488037109375  count: 2000
# time: 0.1707146167755127  count: 3000
# time: 0.17119812965393066  count: 4000
# time: 0.17626166343688965  count: 5000
# time: 0.1829833984375  count: 6000
# time: 0.27887463569641113  count: 7000
# time: 0.3307371139526367  count: 8000
# time: 0.33389925956726074  count: 9000
# time: 0.32243919372558594  count: 10000
# time: 0.37558722496032715  count: 11000
# time: 0.3228487968444824  count: 12000
# time: 0.32256054878234863  count: 13000
# time: 0.31105899810791016  count: 14000
# time: 0.3321256637573242  count: 15000
# time: 0.32652997970581055  count: 16000
# time: 0.3286905288696289  count: 17000
# time: 0.3238065242767334  count: 18000
# time: 0.3290855884552002  count: 19000
# time: 0.32583165168762207  count: 20000
# time: 0.32876014709472656  count: 21000
# time: 0.3682377338409424  count: 22000
# time: 0.3311285972595215  count: 23000
# time: 0.3261077404022217  count: 24000
# time: 0.32872629165649414  count: 25000
# time: 0.3256399631500244  count: 26000
# time: 0.324434757232666  count: 27000
# time: 0.3248720169067383  count: 28000
# time: 0.3274843692779541  count: 29000
# time: 0.3324015140533447  count: 30000
# time: 0.32744526863098145  count: 31000
# time: 0.3255791664123535  count: 32000
# time: 1.1530208587646484  count: 33000
# time: 0.3297386169433594  count: 34000
# time: 0.33524346351623535  count: 35000
# time: 0.3356781005859375  count: 36000
# time: 0.32908177375793457  count: 37000
# time: 0.33043932914733887  count: 38000
# time: 0.32741355895996094  count: 39000
# time: 0.3270399570465088  count: 40000
# time: 0.33014345169067383  count: 41000
# time: 0.3282129764556885  count: 42000
# time: 0.3260159492492676  count: 43000
# time: 1.146507978439331  count: 44000
# time: 0.33215951919555664  count: 45000
# time: 0.32482028007507324  count: 46000
# time: 0.31974267959594727  count: 47000
# time: 0.32510995864868164  count: 48000
# time: 0.32591986656188965  count: 49000
# time: 0.32512497901916504  count: 50000
# time: 0.3274040222167969  count: 51000
# time: 0.3287670612335205  count: 52000
